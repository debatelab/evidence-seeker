# %% [markdown]
# # Testing Pipelines
#
# ## Preprocessing pipeline

# %%
import yaml
from pprint import pprint

from evidence_seeker import (
    PreprocessingWorkflow,
    get_openai_llm
)


config_version = "v0.1"
config_file = "../config.yaml" 

with open(config_file, 'r') as file:
    config_dict = yaml.safe_load(file)
    if config_dict['config_version'] != config_version:
        raise ValueError(f"The version of the config file does not match the used version ({config_version})")
    
#pprint(config_dict)

api_key_name = config_dict['models'][config_dict['used_model']]['api_key_name']
model = config_dict['models'][config_dict['used_model']]['model']
base_url = config_dict['models'][config_dict['used_model']]['base_url']

pw = PreprocessingWorkflow(timeout=60, verbose=False)

llm=get_openai_llm(api_key_name=api_key_name, model=model, base_url=base_url)

result = await pw.run(claim="Climate change is the biggest challenge for human kind.", 
                      llm=llm,
                      config=config_dict)
pprint(result)
# Out:
# Used api key name: kideku_toxicity_app_nim
# Instantiating OpenAILike model (model: meta-llama/Llama-3.1-70B-Instruct, base_url: https://huggingface.co/api/integrations/dgx/v1).
# Analysing ascriptive aspects of claim.
# Analysing descriptive aspects of claim.
# Analysing normative aspects of claim.
# Analysing descriptive aspects of claim.
# {'ascriptive_analysis_event': 'Let\'s break down the claim "Climate change is '
#                               'the biggest challenge for human kind."\n'
#                               '\n'
#                               '**Ascriptions:**\n'
#                               'The claim does not contain any explicit '
#                               'ascriptions. It does not attribute the '
#                               'statement to a specific person, organization, '
#                               'or entity. The claim is presented as a '
#                               'straightforward assertion, without any '
#                               'indication that it is a quote, a belief, or an '
#                               'action attributed to someone or something '
#                               'else.\n'
#                               '\n'
#                               '**Implicit ascriptions:**\n'
#                               'However, one could argue that the claim '
#                               'implicitly ascribes a statement to a general or '
#                               'collective entity, such as "experts," '
#                               '"scientists," or "the international community." '
#                               'The use of the phrase "the biggest challenge '
#                               'for human kind" might suggest that this is a '
#                               'widely accepted or consensus view among experts '
#                               'or international organizations. Nevertheless, '
#                               "this is a weak ascription, and the claim's "
#                               'primary function is to assert a statement '
#                               'rather than attribute it to someone or '
#                               'something specific.\n'
#                               '\n'
#                               '**Ambiguity and vagueness:**\n'
#                               'The claim contains some ambiguity and '
#                               'vagueness:\n'
#                               '\n'
#                               '* What is meant by "the biggest challenge"? Is '
#                               'it the most pressing, the most severe, or the '
#                               'most complex challenge? Different '
#                               'interpretations might lead to varying '
#                               'conclusions.\n'
#                               '* What is the scope of "human kind"? Does it '
#                               'refer to current generations, future '
#                               'generations, or both? This ambiguity might '
#                               "affect the claim's validity or relevance.\n"
#                               '* The claim does not specify a timeframe or a '
#                               'particular aspect of climate change (e.g., '
#                               'mitigation, adaptation, or impacts). This lack '
#                               'of specificity might make it difficult to '
#                               "evaluate the claim's accuracy.\n"
#                               '\n'
#                               'By acknowledging these potential ambiguities '
#                               'and vaguenesses, we can refine our '
#                               'understanding of the claim and develop a more '
#                               'targeted approach to fact-checking.',
#  'claim': 'Climate change is the biggest challenge for human kind.',
#  'descriptive_analysis_event': 'Let\'s break down the claim "Climate change is '
#                                'the biggest challenge for human kind."\n'
#                                '\n'
#                                '**Factual or descriptive statements:**\n'
#                                '\n'
#                                'Upon analysis, I identify the following '
#                                'statements that can be verified or falsified '
#                                'by empirical observation or scientific '
#                                'analysis:\n'
#                                '\n'
#                                '1. **Climate change exists**: This is a '
#                                'factual statement that can be verified through '
#                                'scientific analysis of temperature records, '
#                                'melting of polar ice caps, and other '
#                                'environmental indicators.\n'
#                                '2. **Climate change is a challenge for human '
#                                'kind**: This statement can be considered '
#                                'descriptive, as it implies that climate change '
#                                'has a significant impact on human societies, '
#                                'economies, and ecosystems. This can be '
#                                'verified through studies on the effects of '
#                                'climate change on human health, economic '
#                                'stability, and environmental degradation.\n'
#                                '\n'
#                                '**Implicit statements:**\n'
#                                '\n'
#                                'The claim also implies the following '
#                                'statements, which may require further '
#                                'clarification:\n'
#                                '\n'
#                                '1. **Comparison to other challenges**: The '
#                                'claim implies that climate change is the most '
#                                'significant challenge facing human kind, which '
#                                'raises questions about the criteria used for '
#                                'comparison. What other challenges are being '
#                                'considered, and how are they being weighed '
#                                'against climate change?\n'
#                                '2. **Scope and scale**: The claim does not '
#                                'specify the scope and scale of the challenge '
#                                'posed by climate change. Is it referring to '
#                                'the global community, specific regions, or '
#                                'local populations?\n'
#                                '\n'
#                                '**Ambiguity and vagueness:**\n'
#                                '\n'
#                                'The claim is somewhat vague, as it does not '
#                                'provide a clear definition of what constitutes '
#                                'the "biggest challenge." This could be '
#                                'interpreted in various ways, such as:\n'
#                                '\n'
#                                '* The most pressing challenge in terms of '
#                                'immediate impact\n'
#                                '* The challenge with the most severe long-term '
#                                'consequences\n'
#                                '* The challenge that requires the most '
#                                'significant resources to address\n'
#                                '\n'
#                                'To clarify the claim, it would be helpful to '
#                                'specify the criteria used to evaluate the '
#                                'magnitude of the challenge posed by climate '
#                                'change.\n'
#                                '\n'
#                                'Overall, the claim contains a mix of factual '
#                                'and descriptive statements, with some implicit '
#                                'assumptions and ambiguities that require '
#                                'further clarification.',
#  'list_descriptive_claims_event': '{\n'
#                                   '  "claims": [\n'
#                                   '    {\n'
#                                   '      "claim": "Climate change exists"\n'
#                                   '    },\n'
#                                   '    {\n'
#                                   '      "claim": "Climate change is a '
#                                   'challenge for human kind"\n'
#                                   '    },\n'
#                                   '    {\n'
#                                   '      "claim": "Climate change has a '
#                                   'significant impact on human health"\n'
#                                   '    },\n'
#                                   '    {\n'
#                                   '      "claim": "Climate change has a '
#                                   'significant impact on economic stability"\n'
#                                   '    },\n'
#                                   '    {\n'
#                                   '      "claim": "Climate change has a '
#                                   'significant impact on environmental '
#                                   'degradation"\n'
#                                   '    },\n'
#                                   '    {\n'
#                                   '      "claim": "Climate change is the most '
#                                   'significant challenge facing human kind in '
#                                   'terms of immediate impact"\n'
#                                   '    },\n'
#                                   '    {\n'
#                                   '      "claim": "Climate change is the most '
#                                   'significant challenge facing human kind in '
#                                   'terms of long-term consequences"\n'
#                                   '    },\n'
#                                   '    {\n'
#                                   '      "claim": "Climate change is the '
#                                   'challenge that requires the most '
#                                   'significant resources to address"\n'
#                                   '    }\n'
#                                   '  ]\n'
#                                   '}',
#  'normative_analysis_event': 'Let\'s break down the claim "Climate change is '
#                              'the biggest challenge for human kind."\n'
#                              '\n'
#                              '**Normative statements:**\n'
#                              '\n'
#                              'Upon analysis, I argue that the claim contains a '
#                              'value judgment. The phrase "biggest challenge" '
#                              'implies a ranking or evaluation of the severity '
#                              'or importance of climate change relative to '
#                              'other challenges facing humanity. This '
#                              'evaluation is subjective and depends on the '
#                              'values and priorities of the person or '
#                              'organization making the claim.\n'
#                              '\n'
#                              'In my own words, the implied normative statement '
#                              'is: "Climate change is more significant or '
#                              'pressing than other challenges facing '
#                              'humanity."\n'
#                              '\n'
#                              '**Ambiguity and vagueness:**\n'
#                              '\n'
#                              'There are a few potential sources of ambiguity '
#                              'and vagueness in the claim:\n'
#                              '\n'
#                              '1. **What is meant by "human kind"?** Does this '
#                              'refer to current generations, future '
#                              'generations, or both? Are we considering the '
#                              'impact of climate change on human societies, '
#                              'economies, or individual well-being?\n'
#                              '2. **What is the scope of "challenge"?** Is the '
#                              'claim referring to the environmental, economic, '
#                              'social, or political implications of climate '
#                              'change? Are we considering the challenge of '
#                              'mitigating climate change, adapting to its '
#                              'effects, or both?\n'
#                              '3. **How is "biggest" defined?** Is the claim '
#                              'based on the severity of the impact, the '
#                              'likelihood of occurrence, the number of people '
#                              'affected, or some other metric?\n'
#                              '\n'
#                              'To clarify these ambiguities, it would be '
#                              'helpful to consider alternative interpretations, '
#                              'such as:\n'
#                              '\n'
#                              '* "Climate change is the most significant '
#                              'environmental challenge facing humanity."\n'
#                              '* "Climate change is the most pressing economic '
#                              'challenge for human societies."\n'
#                              '* "Climate change is the most severe threat to '
#                              'human well-being and security."\n'
#                              '\n'
#                              'By acknowledging these potential ambiguities and '
#                              'vaguenesses, we can better understand the claim '
#                              'and develop a more targeted approach to '
#                              'verifying its accuracy.'}

# %%
# %pip install llama-index-utils-workflow

from llama_index.utils.workflow import draw_all_possible_flows
from evidence_seeker import PreprocessingWorkflow

draw_all_possible_flows(PreprocessingWorkflow, filename="preprocessing_workflow_visualisation.html")
# Out:
# <class 'NoneType'>
# <class 'evidence_seeker.preprocessing.AscriptiveAnalysisEndEvent'>
# <class 'evidence_seeker.preprocessing.ListDescriptiveClaimsEvent'>
# <class 'evidence_seeker.preprocessing.DescriptiveAnalysisEndEvent'>
# <class 'evidence_seeker.preprocessing.NormativeAnalysisEndEvent'>
# <class 'evidence_seeker.preprocessing.NormativeAnalysisEvent'>
# <class 'evidence_seeker.preprocessing.DescriptiveAnalysisEvent'>
# <class 'evidence_seeker.preprocessing.AscriptiveAnalysisEvent'>
# <class 'llama_index.core.workflow.events.StopEvent'>
# preprocessing_workflow_visualisation.html
