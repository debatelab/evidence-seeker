# %% [markdown]
# # Testing Pipelines
#
# ## Preprocessing pipeline

# %%
import yaml
from pprint import pprint

from evidence_seeker import (
    PreprocessingWorkflow,
    get_openai_llm
)


config_version = "v0.1"
config_file = "../config.yaml" 

with open(config_file, 'r') as file:
    config_dict = yaml.safe_load(file)
    if config_dict['config_version'] != config_version:
        raise ValueError(f"The version of the config file does not match the used version ({config_version})")
    
#pprint(config_dict)

api_key_name = config_dict['models'][config_dict['used_model']]['api_key_name']
model = config_dict['models'][config_dict['used_model']]['model']
base_url = config_dict['models'][config_dict['used_model']]['base_url']

pw = PreprocessingWorkflow(timeout=60, verbose=False)

llm=get_openai_llm(api_key_name=api_key_name, model=model, base_url=base_url)

result = await pw.run(claim="Climate change is the biggest challenge for human kind.", 
                      llm=llm,
                      config=config_dict)
pprint(result)
# Out:
# Used api key name: kideku_toxicity_app_nim
# Instantiating OpenAILike model (model: meta-llama/Llama-3.1-70B-Instruct, base_url: https://huggingface.co/api/integrations/dgx/v1).
# Analysing ascriptive aspects of claim.
# Analysing descriptive aspects of claim.
# Analysing normative aspects of claim.
# {'ascriptive_analysis_event': 'Let\'s break down the claim "Climate change is '
#                               'the biggest challenge for human kind" and '
#                               'analyze it according to the two tasks.\n'
#                               '\n'
#                               '**Task 1: Ascriptions**\n'
#                               '\n'
#                               'Upon examination, it appears that the claim '
#                               'does not contain any explicit ascriptions. The '
#                               'statement is presented as a straightforward '
#                               'assertion, without attributing it to a specific '
#                               'person, organization, or source. There is no '
#                               'phrase such as "according to '
#                               '[expert/organization]," "as stated by '
#                               '[person]," or "believes [person/organization]" '
#                               'that would indicate an ascription.\n'
#                               '\n'
#                               "However, it's possible to interpret the claim "
#                               'as an implicit ascription, depending on the '
#                               'context in which it is presented. For instance, '
#                               'if this claim is part of a report or article '
#                               'written by a specific author or organization, '
#                               'it could be inferred that the statement '
#                               'reflects the views or opinions of that author '
#                               'or organization. Nevertheless, based solely on '
#                               'the text of the claim itself, there is no '
#                               'explicit ascription.\n'
#                               '\n'
#                               '**Task 2: Ambiguity and Vagueness**\n'
#                               '\n'
#                               'The claim contains some ambiguity and vagueness '
#                               'that should be acknowledged:\n'
#                               '\n'
#                               '* "Climate change" is a broad term that '
#                               'encompasses various aspects, such as global '
#                               'warming, sea-level rise, extreme weather '
#                               "events, and more. It's unclear which specific "
#                               'aspect(s) of climate change the claim is '
#                               'referring to.\n'
#                               '* "Biggest challenge" is a subjective '
#                               'evaluation that can be interpreted in different '
#                               'ways. What criteria are being used to determine '
#                               'the "biggest" challenge? Is it the severity of '
#                               'the impact, the number of people affected, the '
#                               'economic costs, or something else?\n'
#                               '* "For human kind" is a vague phrase that could '
#                               'be interpreted as referring to the global '
#                               'population, specific communities, or future '
#                               "generations. It's unclear which group(s) the "
#                               'claim is intended to encompass.\n'
#                               '\n'
#                               'To clarify the claim and facilitate '
#                               'fact-checking, it would be helpful to provide '
#                               'more context or specificity regarding these '
#                               'ambiguous and vague aspects.',
#  'claim': 'Climate change is the biggest challenge for human kind.',
#  'descriptive_analysis_event': 'Let\'s break down the claim "Climate change is '
#                                'the biggest challenge for human kind" and '
#                                'analyze its components.\n'
#                                '\n'
#                                '**Factual/Descriptive Statements:**\n'
#                                '\n'
#                                '1. "Climate change" is a factual concept that '
#                                'refers to the long-term warming of the planet, '
#                                'which is supported by scientific evidence and '
#                                'data. This part of the claim can be verified '
#                                'or falsified through empirical observation and '
#                                'scientific analysis.\n'
#                                '2. "Biggest challenge for human kind" is a '
#                                'descriptive statement that implies a value '
#                                'judgment. It suggests that climate change is '
#                                'the most significant or pressing issue facing '
#                                'humanity, which is a subjective assessment.\n'
#                                '\n'
#                                '**Ambiguity and Vagueness:**\n'
#                                '\n'
#                                '1. The term "biggest challenge" is vague, as '
#                                "it doesn't specify what criteria are being "
#                                'used to evaluate the challenge. Is it the most '
#                                'pressing issue in terms of immediate impact, '
#                                'long-term consequences, economic costs, or '
#                                'human suffering? Different interpretations of '
#                                '"biggest challenge" might lead to varying '
#                                'conclusions.\n'
#                                '2. The phrase "for human kind" is also '
#                                'ambiguous. Does it refer to the current '
#                                'generation, future generations, or the entire '
#                                'human species? This ambiguity might affect how '
#                                'one evaluates the claim, as the challenges '
#                                'posed by climate change may vary across '
#                                'different time scales and populations.\n'
#                                "3. The claim doesn't specify what is meant by "
#                                '"challenge." Is it referring to the severity '
#                                'of the problem, the difficulty of addressing '
#                                'it, or the potential consequences of inaction? '
#                                'Different interpretations of "challenge" might '
#                                'lead to different conclusions about the '
#                                'claim.\n'
#                                '\n'
#                                '**Alternative Interpretations:**\n'
#                                '\n'
#                                '1. One possible interpretation is that climate '
#                                'change is the most significant environmental '
#                                'challenge facing humanity, given its potential '
#                                'to cause widespread devastation, displacement, '
#                                'and economic disruption.\n'
#                                '2. Another interpretation is that climate '
#                                'change is the most pressing issue in terms of '
#                                'its potential to exacerbate existing social '
#                                'and economic inequalities, particularly for '
#                                'vulnerable populations.\n'
#                                '3. A third interpretation might be that '
#                                'climate change is the biggest challenge in '
#                                'terms of its complexity, requiring a '
#                                'coordinated global response and significant '
#                                'technological, economic, and political '
#                                'transformations.\n'
#                                '\n'
#                                'By acknowledging these ambiguities and '
#                                'alternative interpretations, we can better '
#                                'understand the nuances of the claim and '
#                                'develop a more targeted approach to verifying '
#                                'or falsifying its factual components.',
#  'normative_analysis_event': 'Let\'s break down the claim "Climate change is '
#                              'the biggest challenge for human kind" and '
#                              'analyze it carefully.\n'
#                              '\n'
#                              '**Normative statements:**\n'
#                              '\n'
#                              'Upon examination, I argue that the claim '
#                              'contains a value judgment. The phrase "biggest '
#                              'challenge" implies a ranking or evaluation of '
#                              'the severity or importance of climate change '
#                              'relative to other challenges facing humanity. '
#                              'This evaluation is subjective and depends on the '
#                              'values and priorities of the person or '
#                              'organization making the claim.\n'
#                              '\n'
#                              'In my own words, the implied normative statement '
#                              'could be: "Climate change is more important or '
#                              'pressing than other challenges facing humanity, '
#                              'and therefore deserves more attention and '
#                              'resources."\n'
#                              '\n'
#                              '**Ambiguity and vagueness:**\n'
#                              '\n'
#                              'There are a few areas of ambiguity and vagueness '
#                              'in the claim:\n'
#                              '\n'
#                              '1. **What is meant by "human kind"?** Does it '
#                              'refer to the entire human species, or a specific '
#                              'subset of people (e.g., a particular region, '
#                              'country, or socioeconomic group)? Different '
#                              'interpretations of "human kind" might lead to '
#                              'varying assessments of the challenge posed by '
#                              'climate change.\n'
#                              '2. **What is the scope of "challenge"?** Does it '
#                              'encompass only environmental impacts, or also '
#                              'economic, social, and political consequences? A '
#                              'broader or narrower definition of "challenge" '
#                              'could influence the evaluation of climate '
#                              "change's relative importance.\n"
#                              '3. **What is the timeframe considered?** Is the '
#                              'claim referring to the present moment, the near '
#                              'future, or a longer-term perspective? Climate '
#                              'change is a long-term process, and its impacts '
#                              'may unfold over decades or centuries. The '
#                              'timeframe considered could affect the assessment '
#                              'of its relative importance.\n'
#                              '4. **How is "biggest" defined?** Is it in terms '
#                              'of the number of people affected, the severity '
#                              'of impacts, the economic costs, or something '
#                              'else? Different metrics for evaluating the '
#                              '"bigness" of a challenge could lead to varying '
#                              'conclusions.\n'
#                              '\n'
#                              'By acknowledging these ambiguities and '
#                              'vagueness, we can better understand the nuances '
#                              'of the claim and the potential for different '
#                              'interpretations. This analysis will help us to '
#                              'retrieve more targeted and relevant evidence '
#                              'items to support or challenge the claim.'}
