# %% [markdown]
# # Testing Pipelines
#
# ## Preprocessing pipeline

# %%
import yaml
from pprint import pprint

from evidence_seeker import (
    PreprocessingWorkflow,
    get_openai_llm
)


config_version = "v0.1"
config_file = "../config.yaml" 

with open(config_file, 'r') as file:
    config_dict = yaml.safe_load(file)
    if config_dict['config_version'] != config_version:
        raise ValueError(f"The version of the config file does not match the used version ({config_version})")
    
#pprint(config_dict)

api_key_name = config_dict['models'][config_dict['used_model']]['api_key_name']
model = config_dict['models'][config_dict['used_model']]['model']
base_url = config_dict['models'][config_dict['used_model']]['base_url']

pw = PreprocessingWorkflow(timeout=60, verbose=False)

llm=get_openai_llm(api_key_name=api_key_name, model=model, base_url=base_url)

result = await pw.run(claim="Climate change is the biggest challenge for human kind.", 
                      llm=llm,
                      config=config_dict)
pprint(result)
# Out:
# Used api key name: kideku_toxicity_app_nim
# Instantiating OpenAILike model (model: meta-llama/Llama-3.1-70B-Instruct, base_url: https://huggingface.co/api/integrations/dgx/v1).
# Analysing ascriptive aspects of claim.
# Analysing descriptive aspects of claim.
# Analysing normative aspects of claim.
# {'ascriptive_analysis_event': 'Let\'s break down the claim "Climate change is '
#                               'the biggest challenge for human kind" and '
#                               'analyze it according to the two tasks.\n'
#                               '\n'
#                               '**Task 1: Ascriptions**\n'
#                               '\n'
#                               'Upon examination, it appears that the claim '
#                               'does not contain any explicit ascriptions. The '
#                               'statement is presented as a straightforward '
#                               'assertion, without attributing it to a specific '
#                               'person, organization, or source. There is no '
#                               'phrase such as "according to '
#                               '[expert/organization]," "as stated by '
#                               '[person]," or "believes [person/organization]" '
#                               'that would indicate an ascription.\n'
#                               '\n'
#                               "However, it's possible to interpret the claim "
#                               'as an implicit ascription, depending on the '
#                               'context in which it is presented. For instance, '
#                               'if this claim is part of a report or article '
#                               'written by a specific author or organization, '
#                               'it could be inferred that the statement '
#                               'reflects the views or opinions of that author '
#                               'or organization. Nevertheless, based solely on '
#                               'the text of the claim itself, there is no '
#                               'explicit ascription.\n'
#                               '\n'
#                               '**Task 2: Ambiguity and Vagueness**\n'
#                               '\n'
#                               'The claim contains some ambiguity and vagueness '
#                               'that should be acknowledged:\n'
#                               '\n'
#                               '* "Climate change" is a broad term that '
#                               'encompasses various aspects, such as global '
#                               'warming, sea-level rise, extreme weather '
#                               "events, and more. It's unclear which specific "
#                               'aspect(s) of climate change the claim is '
#                               'referring to.\n'
#                               '* "Biggest challenge" is a subjective '
#                               'evaluation that can be interpreted in different '
#                               'ways. What criteria are being used to determine '
#                               'the "biggest" challenge? Is it the severity of '
#                               'the impact, the number of people affected, the '
#                               'economic costs, or something else?\n'
#                               '* "For human kind" is a vague phrase that could '
#                               'be interpreted as referring to the global '
#                               'population, specific communities, or future '
#                               "generations. It's unclear which group(s) the "
#                               'claim is intended to encompass.\n'
#                               '\n'
#                               'To clarify the claim and facilitate '
#                               'fact-checking, it would be helpful to provide '
#                               'more context or specificity regarding these '
#                               'ambiguous and vague aspects.',
#  'claim': 'Climate change is the biggest challenge for human kind.',
#  'descriptive_analysis_event': 'Let\'s break down the claim "Climate change is '
#                                'the biggest challenge for human kind" and '
#                                'analyze its components.\n'
#                                '\n'
#                                '**Factual/Descriptive Statements:**\n'
#                                '\n'
#                                '1. "Climate change" is a factual concept that '
#                                'refers to the long-term warming of the planet, '
#                                'which is supported by scientific evidence and '
#                                'data. This part of the claim can be verified '
#                                'or falsified through empirical observation and '
#                                'scientific analysis.\n'
#                                '2. "Biggest challenge for human kind" is a '
#                                'descriptive statement that implies a value '
#                                'judgment. It suggests that climate change is '
#                                'the most significant or pressing issue facing '
#                                'humanity, which is a subjective assessment.\n'
#                                '\n'
#                                '**Ambiguity and Vagueness:**\n'
#                                '\n'
#                                '1. The term "biggest challenge" is vague, as '
#                                "it doesn't specify what criteria are being "
#                                'used to evaluate the challenge. Is it the most '
#                                'pressing issue in terms of immediate impact, '
#                                'long-term consequences, economic costs, or '
#                                'human suffering? Different interpretations of '
#                                '"biggest challenge" might lead to varying '
#                                'conclusions.\n'
#                                '2. The phrase "for human kind" is also '
#                                'ambiguous. Does it refer to the current '
#                                'generation, future generations, or the entire '
#                                'human species? This ambiguity might affect how '
#                                'one evaluates the claim, as the challenges '
#                                'posed by climate change may vary across '
#                                'different time scales and populations.\n'
#                                "3. The claim doesn't specify what is meant by "
#                                '"challenge." Is it referring to the severity '
#                                'of the problem, the difficulty of addressing '
#                                'it, or the potential consequences of inaction? '
#                                'Different interpretations of "challenge" might '
#                                'lead to different conclusions about the '
#                                'claim.\n'
#                                '\n'
#                                '**Alternative Interpretations:**\n'
#                                '\n'
#                                '1. One possible interpretation is that climate '
#                                'change is the most significant environmental '
#                                'challenge facing humanity, given its potential '
#                                'to cause widespread devastation, displacement, '
#                                'and economic disruption.\n'
#                                '2. Another interpretation is that climate '
#                                'change is the most pressing issue in terms of '
#                                'its potential to exacerbate existing social '
#                                'and economic inequalities, particularly for '
#                                'vulnerable populations.\n'
#                                '3. A third interpretation might be that '
#                                'climate change is the biggest challenge in '
#                                'terms of its complexity, requiring a '
#                                'coordinated global response and significant '
#                                'technological, economic, and political '
#                                'transformations.\n'
#                                '\n'
#                                'By acknowledging these ambiguities and '
#                                'alternative interpretations, we can better '
#                                'understand the nuances of the claim and '
#                                'develop a more targeted approach to verifying '
#                                'or falsifying its factual components.',
#  'normative_analysis_event': 'Let\'s break down the claim "Climate change is '
#                              'the biggest challenge for human kind" and '
#                              'analyze it carefully.\n'
#                              '\n'
#                              '**Normative statements:**\n'
#                              '\n'
#                              'Upon examination, I argue that the claim '
#                              'contains a value judgment. The phrase "biggest '
#                              'challenge" implies a ranking or evaluation of '
#                              'the severity or importance of climate change '
#                              'relative to other challenges facing humanity. '
#                              'This evaluation is subjective and depends on the '
#                              'values and priorities of the person or '
#                              'organization making the claim.\n'
#                              '\n'
#                              'In my own words, the implied normative statement '
#                              'could be: "Climate change is more important or '
#                              'pressing than other challenges facing humanity, '
#                              'and therefore deserves more attention and '
#                              'resources."\n'
#                              '\n'
#                              '**Ambiguity and vagueness:**\n'
#                              '\n'
#                              'There are a few areas of ambiguity and vagueness '
#                              'in the claim:\n'
#                              '\n'
#                              '1. **What is meant by "human kind"?** Does it '
#                              'refer to the entire human species, or a specific '
#                              'subset of people (e.g., a particular region, '
#                              'country, or socioeconomic group)? Different '
#                              'interpretations of "human kind" might lead to '
#                              'varying assessments of the challenge posed by '
#                              'climate change.\n'
#                              '2. **What is the scope of "challenge"?** Does it '
#                              'encompass only environmental impacts, or also '
#                              'economic, social, and political consequences? A '
#                              'broader or narrower definition of "challenge" '
#                              'could influence the evaluation of climate '
#                              "change's relative importance.\n"
#                              '3. **What is the timeframe considered?** Is the '
#                              'claim referring to the present moment, the near '
#                              'future, or a longer-term perspective? Climate '
#                              'change is a long-term process, and its impacts '
#                              'may unfold over decades or centuries. The '
#                              'timeframe considered could affect the assessment '
#                              'of its relative importance.\n'
#                              '4. **How is "biggest" defined?** Is it in terms '
#                              'of the number of people affected, the severity '
#                              'of impacts, the economic costs, or something '
#                              'else? Different metrics for evaluating the '
#                              '"bigness" of a challenge could lead to varying '
#                              'conclusions.\n'
#                              '\n'
#                              'By acknowledging these ambiguities and '
#                              'vagueness, we can better understand the nuances '
#                              'of the claim and the potential for different '
#                              'interpretations. This analysis will help us to '
#                              'retrieve more targeted and relevant evidence '
#                              'items to support or challenge the claim.'}

# %%
# %pip install llama-index-utils-workflow

from llama_index.utils.workflow import draw_all_possible_flows
from evidence_seeker import PreprocessingWorkflow

draw_all_possible_flows(PreprocessingWorkflow, filename="preprocessing_workflow_visualisation.html")
# Out:
# Requirement already satisfied: llama-index-utils-workflow in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (0.3.0)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from llama-index-utils-workflow) (0.12.1)
# Requirement already satisfied: pyvis<0.4.0,>=0.3.2 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from llama-index-utils-workflow) (0.3.2)
# Requirement already satisfied: PyYAML>=6.0.1 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (3.10.5)
# Requirement already satisfied: dataclasses-json in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (2024.5.0)
# Requirement already satisfied: httpx in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (3.3)
# Requirement already satisfied: nltk>3.8.1 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (3.9.1)
# Requirement already satisfied: numpy in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (10.4.0)
# Requirement already satisfied: pydantic<2.10.0,>=2.7.0 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (2.9.2)
# Requirement already satisfied: requests>=2.31.0 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (0.9.0)
# Requirement already satisfied: wrapt in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (1.17.0)
# Requirement already satisfied: ipython>=5.3.0 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (8.26.0)
# Requirement already satisfied: jinja2>=2.9.6 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (3.1.4)
# Requirement already satisfied: jsonpickle>=1.4.1 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (4.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (4.0.3)
# Requirement already satisfied: decorator in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (2.18.0)
# Requirement already satisfied: stack-data in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (0.6.2)
# Requirement already satisfied: traitlets>=5.13.0 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (5.14.3)
# Requirement already satisfied: exceptiongroup in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from jinja2>=2.9.6->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (2.1.5)
# Requirement already satisfied: click in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (8.1.7)
# Requirement already satisfied: joblib in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (2024.7.24)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from pydantic<2.10.0,>=2.7.0->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from pydantic<2.10.0,>=2.7.0->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (3.21.3)
# Requirement already satisfied: anyio in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (4.4.0)
# Requirement already satisfied: httpcore==1.* in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (1.0.5)
# Requirement already satisfied: sniffio in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (0.8.4)
# Requirement already satisfied: packaging>=17.0 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-utils-workflow) (24.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (0.7.0)
# Requirement already satisfied: wcwidth in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (2.4.1)
# Requirement already satisfied: pure-eval in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (0.2.3)
# Requirement already satisfied: six>=1.12.0 in /home/sebastian/anaconda3/envs/py-3.10-llm/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=5.3.0->pyvis<0.4.0,>=0.3.2->llama-index-utils-workflow) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# <class 'NoneType'>
# <class 'evidence_seeker.preprocessing.AscriptiveAnalysisEndEvent'>
# <class 'evidence_seeker.preprocessing.DescriptiveAnalysisEndEvent'>
# <class 'evidence_seeker.preprocessing.NormativeAnalysisEndEvent'>
# <class 'evidence_seeker.preprocessing.NormativeAnalysisEvent'>
# <class 'evidence_seeker.preprocessing.DescriptiveAnalysisEvent'>
# <class 'evidence_seeker.preprocessing.AscriptiveAnalysisEvent'>
# <class 'llama_index.core.workflow.events.StopEvent'>
# preprocessing_workflow_visualisation.html
